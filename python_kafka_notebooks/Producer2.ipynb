# %%
## Get Data Imports
from google.transit import gtfs_realtime_pb2
from google.protobuf.json_format import MessageToDict
import requests

## Kafka Imports
import json
from json import dumps
from kafka import KafkaProducer
from time import sleep

# %%
## Global Variables
URL = 'http://transitdata.cityofmadison.com/TripUpdate/TripUpdates.pb'
KAFKA_ADDRESS = '10.128.0.3' ## Internal IP of KafkaVM
KAFKA_TOPIC = 'TripUpdates'

# %%
## Get Feed from URL
FEED = gtfs_realtime_pb2.FeedMessage()
RESPONSE = requests.get(URL)

# %%
## Kafka Producer
producer = KafkaProducer(bootstrap_servers = [KAFKA_ADDRESS + ":9092"],
                      sasl_mechanism = 'PLAIN',
                      sasl_plain_username = 'admin',
                      sasl_plain_password = '2d15dc73ddb202b5bfa5f451bd684ffc25bf651a987cbe6a0f541239e94377db',
                      security_protocol = 'SASL_PLAINTEXT',
                      api_version=(0,11,5),
                      key_serializer = lambda x: dumps(x).encode('utf-8'),
                      value_serializer = lambda x: dumps(x).encode('utf-8'),
                      acks = 1, ## Default -> Broker Recieve Ack
                      batch_size = 16384, ## Default Value
                      compression_type = 'gzip')

## Parse Response String
FEED.ParseFromString(RESPONSE.content)

## Send to Kafka Topic
for idx, elem in enumerate(FEED.entity):
    print("sending index:", idx)
    producer.send(KAFKA_TOPIC, key= {"id": elem.id}, value=MessageToDict(elem)).get(timeout=30)
# Out:
# sending index: 0
# sending index: 1
# sending index: 2
# sending index: 3
# sending index: 4
# sending index: 5
# sending index: 6
# sending index: 7
# sending index: 8
# sending index: 9
# sending index: 10
# sending index: 11
# sending index: 12
# sending index: 13
# sending index: 14
# sending index: 15
# sending index: 16
# sending index: 17
# sending index: 18
# sending index: 19
# sending index: 20
# sending index: 21
# sending index: 22
# sending index: 23
# sending index: 24
# sending index: 25
# sending index: 26
# sending index: 27
# sending index: 28
# sending index: 29
# sending index: 30
# sending index: 31

# %%
MessageToDict(FEED.entity[1])
# Out:
# {'id': '1132903',
#  'tripUpdate': {'trip': {'tripId': '1132903',
#    'startTime': '11:15:00',
#    'startDate': '20230702',
#    'routeId': '10465'},
#   'stopTimeUpdate': [{'stopSequence': 39,
#     'departure': {'delay': 60, 'time': '1688316838'},
#     'stopId': '1883'},
#    {'stopSequence': 40,
#     'departure': {'delay': 60, 'time': '1688316894'},
#     'stopId': '1513'},
#    {'stopSequence': 41,
#     'departure': {'delay': 60, 'time': '1688316946'},
#     'stopId': '1241'},
#    {'stopSequence': 42,
#     'departure': {'delay': 60, 'time': '1688316984'},
#     'stopId': '1107'},
#    {'stopSequence': 43,
#     'departure': {'delay': 60, 'time': '1688317034'},
#     'stopId': '1141'},
#    {'stopSequence': 44,
#     'departure': {'delay': 60, 'time': '1688317092'},
#     'stopId': '1233'},
#    {'stopSequence': 45,
#     'departure': {'delay': 60, 'time': '1688317140'},
#     'stopId': '1311'},
#    {'stopSequence': 46,
#     'departure': {'delay': 60, 'time': '1688317192'},
#     'stopId': '1269'},
#    {'stopSequence': 47,
#     'departure': {'delay': 60, 'time': '1688317229'},
#     'stopId': '1481'},
#    {'stopSequence': 48,
#     'departure': {'delay': 60, 'time': '1688317264'},
#     'stopId': '1757'},
#    {'stopSequence': 49,
#     'departure': {'delay': 60, 'time': '1688317322'},
#     'stopId': '9339'},
#    {'stopSequence': 50,
#     'departure': {'delay': 60, 'time': '1688317357'},
#     'stopId': '9135'},
#    {'stopSequence': 51,
#     'departure': {'delay': 60, 'time': '1688317407'},
#     'stopId': '9405'},
#    {'stopSequence': 52,
#     'departure': {'delay': 60, 'time': '1688317454'},
#     'stopId': '9171'},
#    {'stopSequence': 53,
#     'departure': {'delay': 60, 'time': '1688317500'},
#     'stopId': '9675',
#     'scheduleRelationship': 'SKIPPED'},
#    {'stopSequence': 54,
#     'departure': {'delay': 60, 'time': '1688317540'},
#     'stopId': '9201',
#     'scheduleRelationship': 'SKIPPED'},
#    {'stopSequence': 55,
#     'departure': {'delay': 60, 'time': '1688317630'},
#     'stopId': '9551'},
#    {'stopSequence': 56,
#     'departure': {'delay': 60, 'time': '1688317660'},
#     'stopId': '9573'},
#    {'stopSequence': 57,
#     'departure': {'delay': 60, 'time': '1688317709'},
#     'stopId': '9491'},
#    {'stopSequence': 58,
#     'departure': {'delay': 60, 'time': '1688317756'},
#     'stopId': '9587'},
#    {'stopSequence': 59,
#     'departure': {'delay': 60, 'time': '1688317811'},
#     'stopId': '9139'},
#    {'stopSequence': 60,
#     'departure': {'delay': 60, 'time': '1688317841'},
#     'stopId': '9163'},
#    {'stopSequence': 61,
#     'departure': {'delay': 60, 'time': '1688317875'},
#     'stopId': '9321',
#     'scheduleRelationship': 'SKIPPED'},
#    {'stopSequence': 62,
#     'departure': {'delay': 60, 'time': '1688317920'},
#     'stopId': '9343',
#     'scheduleRelationship': 'SKIPPED'},
#    {'stopSequence': 63,
#     'departure': {'delay': 60, 'time': '1688317984'},
#     'stopId': '9701'},
#    {'stopSequence': 64,
#     'departure': {'delay': 60, 'time': '1688318090'},
#     'stopId': '9577'},
#    {'stopSequence': 65,
#     'departure': {'delay': 60, 'time': '1688318134'},
#     'stopId': '9273'},
#    {'stopSequence': 66,
#     'departure': {'delay': 60, 'time': '1688318220'},
#     'stopId': '9509'},
#    {'stopSequence': 67,
#     'arrival': {'delay': 60, 'time': '1688318640'},
#     'stopId': '9001'}],
#   'vehicle': {'id': '2461', 'label': '983'},
#   'timestamp': '1688317095'}}
